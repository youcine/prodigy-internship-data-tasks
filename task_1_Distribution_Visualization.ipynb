# %% [markdown]
# <a href="https://colab.research.google.com/github/youcine/Prodigy_infoTech_internship/blob/main/task_1_prodigy_infotech_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing Data and neccesery liberies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **uploding** DATA

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Prodigy infoTech internship/population.csv', encoding='latin-1')
dataset.head()
# Out:
#    MUNICIPALITY REFNIS CODE MUNICIPALITY NAME  DISTRICT REFNIS CODE  \
# 0                     71024      Herk-de-Stad                 71000
# 1                     71037            Lummen                 71000
# 2                     71011        Diepenbeek                 71000
# 3                     71016              Genk                 71000
# 4                     71017          Gingelom                 71000
#
#   DISTRICT NAME  PROVINCE REFNIS CODE PROVINCE NAME  REGION REFNIS CODE  \
# 0       Hasselt               70000.0       Limburg                2000
# 1       Hasselt               70000.0       Limburg                2000
# 2       Hasselt               70000.0       Limburg                2000
# 3       Hasselt               70000.0       Limburg                2000
# 4       Hasselt               70000.0       Limburg                2000
#
#       REGION NAME GENDER NATIONALITY CIVIL CODE STATUS  AGE  POPULATION
# 0  Flemish Region      F     Belgian           Married   39          42
# 1  Flemish Region      M     Belgian           Married   82          24
# 2  Flemish Region      F     Belgian           Married   42          51
# 3  Flemish Region      M     Belgian           Married   63         277
# 4  Flemish Region      F     Belgian           Married   30          14

# %% [markdown]
# **Exploring Data**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465418 entries, 0 to 465417
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   MUNICIPALITY REFNIS CODE  465418 non-null  int64
#  1   MUNICIPALITY NAME         465418 non-null  object
#  2   DISTRICT REFNIS CODE      465418 non-null  int64
#  3   DISTRICT NAME             465418 non-null  object
#  4   PROVINCE REFNIS CODE      443993 non-null  float64
#  5   PROVINCE NAME             443993 non-null  object
#  6   REGION REFNIS CODE        465418 non-null  int64
#  7   REGION NAME               465418 non-null  object
#  8   GENDER                    465418 non-null  object
#  9   NATIONALITY               465418 non-null  object
#  10  CIVIL CODE STATUS         465418 non-null  object
#  11  AGE                       465418 non-null  int64
#  12  POPULATION                465418 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 46.2+ MB

# %%
dataset.describe()
# Out:
#        MUNICIPALITY REFNIS CODE  DISTRICT REFNIS CODE  PROVINCE REFNIS CODE  \
# count             465418.000000         465418.000000         443993.000000
# mean               45795.085029          45754.592646          43842.168913
# std                23956.614057          23950.946921          24106.756939
# min                11001.000000          11000.000000          10000.000000
# 25%                24033.000000          24000.000000          20002.000000
# 50%                44043.000000          44000.000000          40000.000000
# 75%                63035.000000          63000.000000          60000.000000
# max                93090.000000          93000.000000          90000.000000
#
#        REGION REFNIS CODE            AGE     POPULATION
# count       465418.000000  465418.000000  465418.000000
# mean          2517.923673      52.607527      24.442695
# std            584.591526      23.467469      63.746827
# min           2000.000000       0.000000       1.000000
# 25%           2000.000000      35.000000       2.000000
# 50%           2000.000000      53.000000       7.000000
# 75%           3000.000000      71.000000      25.000000
# max           4000.000000     100.000000    2936.000000

# %% [markdown]
# Handle Missing Data

# %%
dataset.isna()
print(dataset)
# Out:
#         MUNICIPALITY REFNIS CODE MUNICIPALITY NAME  DISTRICT REFNIS CODE  \
# 0                          71024      Herk-de-Stad                 71000
# 1                          71037            Lummen                 71000
# 2                          71011        Diepenbeek                 71000
# 3                          71016              Genk                 71000
# 4                          71017          Gingelom                 71000
# ...                          ...               ...                   ...
# 465413                     92141        La Bruyère                 92000
# 465414                     46024           Stekene                 46000
# 465415                     46024           Stekene                 46000
# 465416                     46024           Stekene                 46000
# 465417                     92141        La Bruyère                 92000
#
#         DISTRICT NAME  PROVINCE REFNIS CODE     PROVINCE NAME  \
# 0             Hasselt               70000.0           Limburg
# 1             Hasselt               70000.0           Limburg
# 2             Hasselt               70000.0           Limburg
# 3             Hasselt               70000.0           Limburg
# 4             Hasselt               70000.0           Limburg
# ...               ...                   ...               ...
# 465413          Namen               90000.0             Namen
# 465414   Sint-Niklaas               40000.0   Oost-Vlaanderen
# 465415   Sint-Niklaas               40000.0   Oost-Vlaanderen
# 465416   Sint-Niklaas               40000.0   Oost-Vlaanderen
# 465417          Namen               90000.0             Namen
#
#         REGION REFNIS CODE     REGION NAME GENDER NATIONALITY  \
# 0                     2000  Flemish Region      F     Belgian
# 1                     2000  Flemish Region      M     Belgian
# 2                     2000  Flemish Region      F     Belgian
# 3                     2000  Flemish Region      M     Belgian
# 4                     2000  Flemish Region      F     Belgian
# ...                    ...             ...    ...         ...
# 465413                3000  Walloon Region      F       Alien
# 465414                2000  Flemish Region      M       Alien
# 465415                2000  Flemish Region      M       Alien
# 465416                2000  Flemish Region      M       Alien
# 465417                3000  Walloon Region      F       Alien
#
#        CIVIL CODE STATUS  AGE  POPULATION
# 0                Married   39          42
# 1                Married   82          24
# 2                Married   42          51
# 3                Married   63         277
# 4                Married   30          14
# ...                  ...  ...         ...
# 465413          Divorced   64           1
# 465414          Divorced   67           2
# 465415          Divorced   74           1
# 465416          Divorced   81           1
# 465417          Divorced   63           1
#
# [465418 rows x 13 columns]

# %%
(dataset.isna()).value_counts()
# Out:
# MUNICIPALITY REFNIS CODE  MUNICIPALITY NAME  DISTRICT REFNIS CODE  DISTRICT NAME  PROVINCE REFNIS CODE  PROVINCE NAME  REGION REFNIS CODE  REGION NAME  GENDER  NATIONALITY  CIVIL CODE STATUS  AGE    POPULATION
# False                     False              False                 False          False                 False          False               False        False   False        False              False  False         443993
#                                                                                   True                  True           False               False        False   False        False              False  False          21425
# dtype: int64

# %%
dataset.isna()
# Out:
#         MUNICIPALITY REFNIS CODE  MUNICIPALITY NAME  DISTRICT REFNIS CODE  \
# 0                          False              False                 False
# 1                          False              False                 False
# 2                          False              False                 False
# 3                          False              False                 False
# 4                          False              False                 False
# ...                          ...                ...                   ...
# 465413                     False              False                 False
# 465414                     False              False                 False
# 465415                     False              False                 False
# 465416                     False              False                 False
# 465417                     False              False                 False
#
#         DISTRICT NAME  PROVINCE REFNIS CODE  PROVINCE NAME  \
# 0               False                 False          False
# 1               False                 False          False
# 2               False                 False          False
# 3               False                 False          False
# 4               False                 False          False
# ...               ...                   ...            ...
# 465413          False                 False          False
# 465414          False                 False          False
# 465415          False                 False          False
# 465416          False                 False          False
# 465417          False                 False          False
#
#         REGION REFNIS CODE  REGION NAME  GENDER  NATIONALITY  \
# 0                    False        False   False        False
# 1                    False        False   False        False
# 2                    False        False   False        False
# 3                    False        False   False        False
# 4                    False        False   False        False
# ...                    ...          ...     ...          ...
# 465413               False        False   False        False
# 465414               False        False   False        False
# 465415               False        False   False        False
# 465416               False        False   False        False
# 465417               False        False   False        False
#
#         CIVIL CODE STATUS    AGE  POPULATION
# 0                   False  False       False
# 1                   False  False       False
# 2                   False  False       False
# 3                   False  False       False
# 4                   False  False       False
# ...                   ...    ...         ...
# 465413              False  False       False
# 465414              False  False       False
# 465415              False  False       False
# 465416              False  False       False
# 465417              False  False       False
#
# [465418 rows x 13 columns]

# %% [markdown]
# # **visualisation **

# %% [markdown]
# Histogram for gender

# %%
dataset = pd.DataFrame(dataset)
plt.figure(figsize=(10, 6))
plt.hist(dataset['AGE'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age Variable')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %%
dataset = pd.DataFrame(dataset)
plt.figure(figsize=(6, 4))
gender_counts = dataset['GENDER'].value_counts()
bar_width = 0.5
plt.bar(gender_counts.index, gender_counts, width=bar_width, color=['pink', 'blue'], edgecolor='black')

plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Gender Variable')
plt.grid(axis='y', alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(8, 6))
civil_code_counts = dataset['CIVIL CODE STATUS'].value_counts()
plt.bar(civil_code_counts.index, civil_code_counts, color='green', edgecolor='black')
plt.xlabel('Civil Code Status')
plt.ylabel('Frequency')
plt.title('Distribution of Civil Code Status in the Population')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(8, 6))
nationality_counts = dataset['NATIONALITY'].value_counts()
plt.bar(nationality_counts.index, nationality_counts, color='orange', edgecolor='black')
plt.xlabel('Nationality')
plt.ylabel('Frequency')
plt.title('Distribution of Nationality in the Population')
plt.grid(axis='y', alpha=0.75)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=dataset, x='AGE', hue='GENDER', bins=20, kde=True, multiple='stack', palette={'M': 'blue', 'F': 'pink'})
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Gender in the Population')
plt.show()

# %%
dataset.nunique()
# Out:
# MUNICIPALITY REFNIS CODE     589
# MUNICIPALITY NAME            589
# DISTRICT REFNIS CODE          43
# DISTRICT NAME                 43
# PROVINCE REFNIS CODE          10
# PROVINCE NAME                 10
# REGION REFNIS CODE             3
# REGION NAME                    3
# GENDER                         2
# NATIONALITY                    2
# CIVIL CODE STATUS              4
# AGE                          101
# POPULATION                  1115
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
province_counts = dataset['PROVINCE NAME'].value_counts()
plt.bar(province_counts.index, province_counts, color='purple', edgecolor='black')
plt.xlabel('Province')
plt.ylabel('Frequency')
plt.title('Distribution of Population Across Provinces')
plt.grid(axis='y', alpha=0.75)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
marital_status_counts = dataset['CIVIL CODE STATUS'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(marital_status_counts, labels=marital_status_counts.index, autopct='%1.1f%%', colors=['skyblue','lightcoral','skyblue','pink'])
plt.title('Distribution of Marital Status')
plt.show()
